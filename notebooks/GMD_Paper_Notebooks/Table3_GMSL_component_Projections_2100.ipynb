# %% [markdown]
# ## <font color=green> *FACTS GMD:* <font color=black> Table 3 </font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import netCDF4 as nc
from pandas.plotting import table 
import xarray as xr

# %% [markdown]
# ### <font color=blue> List of **Modules** and **Data** to be used </font>

# %% [markdown]
# ##### <font color=red> **Global**</font>

# %%
# Load FACTS workflow data.
df_module_global = pd.read_fwf('001_input_Names_Modules_dataFILES/Table3_IP_Component_Module_subModule_DataFile_global.txt',comment = '#') 
#
# Label first column with numbers. (To preserve the table list-structure)
df_module_global['Num'] = np.arange(df_module_global.shape[0])
# shift column No to first position
first_col = df_module_global.pop('Num')
df_module_global.insert(0, 'Num', first_col)
df_module_global
# Out:
#     Num  dataID Component       Module        sub_Module  \
# 0     0   cplng      GSAT         fair       temperature
# 1     1   cplng  Glaciers   emulandice          glaciers
# 2     2   cplng  Glaciers      ipccar5          glaciers
# 3     3  ar5k14  Glaciers       kopp14          glaciers
# 4     4   cplng       AIS     bamber19         icesheets
# 5     5   cplng       AIS    deconto21               AIS
# 6     6   cplng       AIS   emulandice               AIS
# 7     7   cplng       AIS      ipccar5         icesheets
# 8     8  ar5k14       AIS       kopp14         icesheets
# 9     9   cplng       AIS       larmip               AIS
# 10   10   cplng      GrIS     bamber19         icesheets
# 11   11   cplng      GrIS   emulandice              GrIS
# 12   12   cplng      GrIS  FittedISMIP              GrIS
# 13   13  ar5k14      GrIS      ipccar5         icesheets
# 14   14  ar5k14      GrIS       kopp14         icesheets
# 15   15  ar5k14       LWS       kopp14  landwaterstorage
# 16   16   cplng       LWS          ssp  landwaterstorage
# 17   17  ar5k14        TE      ipccar5  thermalexpansion
# 18   18   cplng        TE          tlm     sterodynamics
#
#                                           DataFile
# 0             temperature.fair.temperature_gsat.nc
# 1      emuglaciers.emulandice.glaciers_globalsl.nc
# 2         ar5glaciers.ipccar5.glaciers_globalsl.nc
# 3          k14glaciers.kopp14.glaciers_globalsl.nc
# 4      bamber19.bamber19.icesheets_AIS_globalsl.nc
# 5          deconto21.deconto21.AIS_AIS_globalsl.nc
# 6                emuAIS.emulandice.AIS_globalsl.nc
# 7         ar5AIS.ipccar5.icesheets_AIS_globalsl.nc
# 8    k14icesheets.kopp14.icesheets_AIS_globalsl.nc
# 9                    larmip.larmip.AIS_globalsl.nc
# 10     bamber19.bamber19.icesheets_GIS_globalsl.nc
# 11             emuGrIS.emulandice.GrIS_globalsl.nc
# 12         GrIS1f.FittedISMIP.GrIS_GIS_globalsl.nc
# 13  ar5icesheets.ipccar5.icesheets_GIS_globalsl.nc
# 14   k14icesheets.kopp14.icesheets_GIS_globalsl.nc
# 15      k14lws.kopp14.landwaterstorage_globalsl.nc
# 16            lws.ssp.landwaterstorage_globalsl.nc
# 17      ar5TE.ipccar5.thermalexpansion_globalsl.nc
# 18             ocean.tlm.sterodynamics_globalsl.nc

# %% [markdown]
# ### <font color=blue> Create **Table 3** </font>

# %%
import table_ncTOdf as IP
#
EXPDATE    = 221217                    # Experiment date.
YEAR       = 2100;                     # Percentile Year for the table.   
SCENARIO   = ['ssp126', 'ssp245', 'ssp585'];
SCENARIO_R = ['rcp26', 'rcp45', 'rcp85'];                  
#
df_ptile_global = IP.module_Table_nc(df_module_global,SCENARIO,SCENARIO_R,EXPDATE,YEAR)
#
print('Percentile of GMSL [ median(17th - 83rd) ] in meters for different modules for the year ', YEAR)
display(df_ptile_global)
# Out:
# Percentile of GMSL [ median(17th - 83rd) ] in meters for different modules for the year  2100
# SSP/RCP                                        ssp126/rcp26  \
#
# Num Component Module
# 0   GSAT      fair/temperature           1.63 (1.35 - 1.99)
# 1   Glaciers  emulandice/glaciers        0.09 (0.07 - 0.11)
# 2   Glaciers  ipccar5/glaciers           0.09 (0.07 - 0.12)
# 3   Glaciers  kopp14/glaciers            0.11 (0.08 - 0.14)
# 4   AIS       bamber19/icesheets        0.10 (-0.01 - 0.26)
# 5   AIS       deconto21/AIS              0.08 (0.06 - 0.11)
# 6   AIS       emulandice/AIS             0.08 (0.03 - 0.14)
# 7   AIS       ipccar5/icesheets         0.06 (-0.01 - 0.14)
# 8   AIS       kopp14/icesheets          0.06 (-0.05 - 0.16)
# 9   AIS       larmip/AIS                 0.13 (0.05 - 0.26)
# 10  GrIS      bamber19/icesheets         0.13 (0.07 - 0.30)
# 11  GrIS      emulandice/GrIS            0.05 (0.01 - 0.10)
# 12  GrIS      FittedISMIP/GrIS           0.08 (0.06 - 0.10)
# 13  GrIS      ipccar5/icesheets          0.08 (0.05 - 0.10)
# 14  GrIS      kopp14/icesheets           0.06 (0.03 - 0.11)
# 15  LWS       kopp14/landwaterstorage    0.05 (0.03 - 0.07)
# 16  LWS       ssp/landwaterstorage       0.03 (0.02 - 0.04)
# 17  TE        ipccar5/thermalexpansion   0.15 (0.13 - 0.18)
# 18  TE        tlm/sterodynamics          0.14 (0.11 - 0.17)
#
# SSP/RCP                                        ssp245/rcp45  \
#
# Num Component Module
# 0   GSAT      fair/temperature           2.61 (2.19 - 3.12)
# 1   Glaciers  emulandice/glaciers        0.12 (0.10 - 0.14)
# 2   Glaciers  ipccar5/glaciers           0.12 (0.08 - 0.16)
# 3   Glaciers  kopp14/glaciers            0.13 (0.09 - 0.16)
# 4   AIS       bamber19/icesheets        0.10 (-0.01 - 0.26)
# 5   AIS       deconto21/AIS              0.09 (0.07 - 0.11)
# 6   AIS       emulandice/AIS             0.08 (0.03 - 0.14)
# 7   AIS       ipccar5/icesheets         0.05 (-0.02 - 0.13)
# 8   AIS       kopp14/icesheets          0.05 (-0.06 - 0.16)
# 9   AIS       larmip/AIS                 0.14 (0.05 - 0.29)
# 10  GrIS      bamber19/icesheets         0.13 (0.07 - 0.30)
# 11  GrIS      emulandice/GrIS            0.08 (0.04 - 0.13)
# 12  GrIS      FittedISMIP/GrIS           0.10 (0.08 - 0.12)
# 13  GrIS      ipccar5/icesheets          0.09 (0.07 - 0.13)
# 14  GrIS      kopp14/icesheets           0.08 (0.03 - 0.15)
# 15  LWS       kopp14/landwaterstorage    0.05 (0.03 - 0.07)
# 16  LWS       ssp/landwaterstorage       0.03 (0.02 - 0.04)
# 17  TE        ipccar5/thermalexpansion   0.21 (0.18 - 0.23)
# 18  TE        tlm/sterodynamics          0.19 (0.15 - 0.23)
#
# SSP/RCP                                        ssp585/rcp85
#
# Num Component Module
# 0   GSAT      fair/temperature           4.66 (3.96 - 5.55)
# 1   Glaciers  emulandice/glaciers        0.18 (0.15 - 0.20)
# 2   Glaciers  ipccar5/glaciers           0.16 (0.11 - 0.22)
# 3   Glaciers  kopp14/glaciers            0.17 (0.13 - 0.21)
# 4   AIS       bamber19/icesheets         0.20 (0.02 - 0.57)
# 5   AIS       deconto21/AIS              0.34 (0.19 - 0.53)
# 6   AIS       emulandice/AIS             0.08 (0.03 - 0.14)
# 7   AIS       ipccar5/icesheets         0.04 (-0.04 - 0.11)
# 8   AIS       kopp14/icesheets          0.04 (-0.08 - 0.14)
# 9   AIS       larmip/AIS                 0.15 (0.05 - 0.34)
# 10  GrIS      bamber19/icesheets         0.22 (0.10 - 0.59)
# 11  GrIS      emulandice/GrIS            0.12 (0.08 - 0.18)
# 12  GrIS      FittedISMIP/GrIS           0.14 (0.11 - 0.18)
# 13  GrIS      ipccar5/icesheets          0.16 (0.11 - 0.22)
# 14  GrIS      kopp14/icesheets           0.14 (0.07 - 0.25)
# 15  LWS       kopp14/landwaterstorage    0.05 (0.03 - 0.07)
# 16  LWS       ssp/landwaterstorage       0.03 (0.02 - 0.04)
# 17  TE        ipccar5/thermalexpansion   0.32 (0.28 - 0.36)
# 18  TE        tlm/sterodynamics          0.29 (0.24 - 0.35)

# %%
#print(df_ptile_global.to_latex(index=True, escape=False))
